# %% [markdown]
# #Cual es el problema?
#
# Abandono de clientes (Churn)
#
# Trabajamos con una empresa de telecominucaciones que quiere ***predecir cuales clientes van a abandonar el servicio*** (churn) para tomar acciones perditivas.
#
# Por que es importante?
#
# * Conseguir un cliente nuevo representa entre 5X y 25x mas que retener uno existente.
# * Si podemos predecir quien se va, podemos ofrecer un descuento o llamarlo entra de que cancele.

# %%
import pandas as pandas
import numpy as np 

from sklearn.linear.model_selection import  train_test_split # dividir  data en entraminento y prueba
from sklearn.compose import columTransformer # Para transofrma columnas especificas
from sklearn,procesassing import onehorencoder # Para escalar y codificar variables
from sklearn.linear_model import logisticRegression # modelo de regresión  logistica

# metricas de evaluación  para la clasificación 

from sklearn.metrics import (
    confusion_matrix, # Matriz de confusión
    classification_report, # reporte con presición , recall y f1-score
    accuracy_score, # Porcentaje de predicciones correctar
)
import marplotlib.pyplot as plt
# Out:
#   Cell In[1], line 6
#     from sklearn,procesassing import onehorencoder # Para escalar y codificar variables
#                 ^
# SyntaxError: invalid syntax
